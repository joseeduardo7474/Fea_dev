# %% [markdown]
# Contextualização: Nos ultimos anos, a economia brasileira tem apresentado momentos contrastantes, alternando momentos de expansão e contração da atividade econômica. Nesse sentido, o IBGE desenvolveu três pesquisas mensais que são de fundamental importancia para o acompanhamento do ritmo de crescimento da economia, são elas a Pesquisa Mensal do Comércio (PMC), Pesquisa Mensal de Serviços (PMS) e Pesquisa Industrial Mensal - Produção Física (PIM-PF).
#
# Utilizando a biblioteca sidrapy criada pelo IBGE, importe a série histórica dos três dados e crie um gráfico que mostre a série histórica dos 3 indicadores
#
# OBS: Há uma grande variedade de dados que se podem baixar dentro desses indicadores, como dados month over month, year over year, etc. Nesse exercício, importamos os dados de números índices com ajuste sazonal. Ademais, também existem diversas aberturas que podem ser baixadas, nesse exercicio utilizamos o volume de vendas do varejo ampliado para a pmc, volume de serviços para a pms e industria geral para a pim

# %%
# Importar bibliotecas
import sidrapy as sidra
import pandas as pd

# %% [markdown]
# # PMC

# %%
# Coleta de dados da PMC
dados_brutos = sidra.get_table(
    table_code = "8881",
    territorial_level = "1",
    ibge_territorial_code = "all",
    variable = "7170",
    classifications = {"11046": "56736"}, # Pega dados de volume de vendas, varejo ampliado (com ajuste sazonal)
    period = "all"
)
dados_brutos
# Out:
#                              NC                 NN  \
# 0    Nível Territorial (Código)  Nível Territorial
# 1                             1             Brasil
# 2                             1             Brasil
# 3                             1             Brasil
# 4                             1             Brasil
# ..                          ...                ...
# 251                           1             Brasil
# 252                           1             Brasil
# 253                           1             Brasil
# 254                           1             Brasil
# 255                           1             Brasil
#
#                              MC                 MN          V  \
# 0    Unidade de Medida (Código)  Unidade de Medida      Valor
# 1                            30      Número-índice   47.12431
# 2                            30      Número-índice   48.57653
# 3                            30      Número-índice   47.29331
# 4                            30      Número-índice   47.17616
# ..                          ...                ...        ...
# 251                          30      Número-índice  104.08078
# 252                          30      Número-índice  102.68449
# 253                          30      Número-índice  105.06961
# 254                          30      Número-índice  106.17007
# 255                          30      Número-índice  105.89179
#
#                  D1C     D1N           D2C             D2N                D3C  \
# 0    Brasil (Código)  Brasil  Mês (Código)             Mês  Variável (Código)
# 1                  1  Brasil        200301    janeiro 2003               7170
# 2                  1  Brasil        200302  fevereiro 2003               7170
# 3                  1  Brasil        200303      março 2003               7170
# 4                  1  Brasil        200304      abril 2003               7170
# ..               ...     ...           ...             ...                ...
# 251                1  Brasil        202311   novembro 2023               7170
# 252                1  Brasil        202312   dezembro 2023               7170
# 253                1  Brasil        202401    janeiro 2024               7170
# 254                1  Brasil        202402  fevereiro 2024               7170
# 255                1  Brasil        202403      março 2024               7170
#
#                                                    D3N  \
# 0                                             Variável
# 1    PMC - Número-índice com ajuste sazonal (2022=100)
# 2    PMC - Número-índice com ajuste sazonal (2022=100)
# 3    PMC - Número-índice com ajuste sazonal (2022=100)
# 4    PMC - Número-índice com ajuste sazonal (2022=100)
# ..                                                 ...
# 251  PMC - Número-índice com ajuste sazonal (2022=100)
# 252  PMC - Número-índice com ajuste sazonal (2022=100)
# 253  PMC - Número-índice com ajuste sazonal (2022=100)
# 254  PMC - Número-índice com ajuste sazonal (2022=100)
# 255  PMC - Número-índice com ajuste sazonal (2022=100)
#
#                           D4C  \
# 0    Tipos de índice (Código)
# 1                       56736
# 2                       56736
# 3                       56736
# 4                       56736
# ..                        ...
# 251                     56736
# 252                     56736
# 253                     56736
# 254                     56736
# 255                     56736
#
#                                                    D4N
# 0                                      Tipos de índice
# 1    Índice de volume de vendas no comércio varejis...
# 2    Índice de volume de vendas no comércio varejis...
# 3    Índice de volume de vendas no comércio varejis...
# 4    Índice de volume de vendas no comércio varejis...
# ..                                                 ...
# 251  Índice de volume de vendas no comércio varejis...
# 252  Índice de volume de vendas no comércio varejis...
# 253  Índice de volume de vendas no comércio varejis...
# 254  Índice de volume de vendas no comércio varejis...
# 255  Índice de volume de vendas no comércio varejis...
#
# [256 rows x 13 columns]

# %%
# Tratamendo de dados
pmc = (dados_brutos
    .rename(columns = dados_brutos.iloc[0])
    .drop(0)
    .rename(columns={"Mês (Código)":"Data"})
    .assign(
        Data = lambda x: pd.to_datetime(x.Data, format = "%Y%m"),
        Valor = lambda x: x.Valor.astype(float)
        )
)
pmc = pmc.pivot_table(columns="Variável", values="Valor", index="Data")
pmc = pmc.rename(columns={"PMC - Número-índice com ajuste sazonal (2022=100)":"PMC - SA"})
pmc
# Out:
# Variável     PMC - SA
# Data
# 2003-01-01   47.12431
# 2003-02-01   48.57653
# 2003-03-01   47.29331
# 2003-04-01   47.17616
# 2003-05-01   46.64899
# ...               ...
# 2023-11-01  104.08078
# 2023-12-01  102.68449
# 2024-01-01  105.06961
# 2024-02-01  106.17007
# 2024-03-01  105.89179
#
# [255 rows x 1 columns]

# %% [markdown]
# # PMS

# %%
# Coleta de dados da PMS
dados_brutos = sidra.get_table(
    table_code = "5906",
    territorial_level = "1",
    ibge_territorial_code = "all",
    variable = "7168",
    classifications = {"11046": "56726"}, # Pega dados de volume de serviços (com ajuste sazonal)
    period = "all"
)
dados_brutos
# Out:
#                              NC                 NN  \
# 0    Nível Territorial (Código)  Nível Territorial
# 1                             1             Brasil
# 2                             1             Brasil
# 3                             1             Brasil
# 4                             1             Brasil
# ..                          ...                ...
# 155                           1             Brasil
# 156                           1             Brasil
# 157                           1             Brasil
# 158                           1             Brasil
# 159                           1             Brasil
#
#                              MC                 MN          V  \
# 0    Unidade de Medida (Código)  Unidade de Medida      Valor
# 1                            30      Número-índice   89.15232
# 2                            30      Número-índice   89.19171
# 3                            30      Número-índice   88.93554
# 4                            30      Número-índice   89.71568
# ..                          ...                ...        ...
# 155                          30      Número-índice  102.69172
# 156                          30      Número-índice  103.22510
# 157                          30      Número-índice  103.70421
# 158                          30      Número-índice  102.77024
# 159                          30      Número-índice  103.18500
#
#                  D1C     D1N           D2C             D2N                D3C  \
# 0    Brasil (Código)  Brasil  Mês (Código)             Mês  Variável (Código)
# 1                  1  Brasil        201101    janeiro 2011               7168
# 2                  1  Brasil        201102  fevereiro 2011               7168
# 3                  1  Brasil        201103      março 2011               7168
# 4                  1  Brasil        201104      abril 2011               7168
# ..               ...     ...           ...             ...                ...
# 155                1  Brasil        202311   novembro 2023               7168
# 156                1  Brasil        202312   dezembro 2023               7168
# 157                1  Brasil        202401    janeiro 2024               7168
# 158                1  Brasil        202402  fevereiro 2024               7168
# 159                1  Brasil        202403      março 2024               7168
#
#                                                    D3N  \
# 0                                             Variável
# 1    PMS - Número-índice com ajuste sazonal (2022=100)
# 2    PMS - Número-índice com ajuste sazonal (2022=100)
# 3    PMS - Número-índice com ajuste sazonal (2022=100)
# 4    PMS - Número-índice com ajuste sazonal (2022=100)
# ..                                                 ...
# 155  PMS - Número-índice com ajuste sazonal (2022=100)
# 156  PMS - Número-índice com ajuste sazonal (2022=100)
# 157  PMS - Número-índice com ajuste sazonal (2022=100)
# 158  PMS - Número-índice com ajuste sazonal (2022=100)
# 159  PMS - Número-índice com ajuste sazonal (2022=100)
#
#                           D4C                           D4N
# 0    Tipos de índice (Código)               Tipos de índice
# 1                       56726  Índice de volume de serviços
# 2                       56726  Índice de volume de serviços
# 3                       56726  Índice de volume de serviços
# 4                       56726  Índice de volume de serviços
# ..                        ...                           ...
# 155                     56726  Índice de volume de serviços
# 156                     56726  Índice de volume de serviços
# 157                     56726  Índice de volume de serviços
# 158                     56726  Índice de volume de serviços
# 159                     56726  Índice de volume de serviços
#
# [160 rows x 13 columns]

# %%
# Tratamendo de dados
pms = (dados_brutos
    .rename(columns = dados_brutos.iloc[0])
    .drop(0)
    .rename(columns={"Mês (Código)":"Data"})
    .assign(
        Data = lambda x: pd.to_datetime(x.Data, format = "%Y%m"),
        Valor = lambda x: x.Valor.astype(float)
        )
)
pms = pms.pivot_table(columns="Variável", values="Valor", index="Data")
pms = pms.rename(columns={"PMS - Número-índice com ajuste sazonal (2022=100)":"PMS - SA"})
pms
# Out:
# Variável     PMS - SA
# Data
# 2011-01-01   89.15232
# 2011-02-01   89.19171
# 2011-03-01   88.93554
# 2011-04-01   89.71568
# 2011-05-01   90.22346
# ...               ...
# 2023-11-01  102.69172
# 2023-12-01  103.22510
# 2024-01-01  103.70421
# 2024-02-01  102.77024
# 2024-03-01  103.18500
#
# [159 rows x 1 columns]

# %% [markdown]
# # PIM

# %%
# Coleta de dados da PIM
dados_brutos = sidra.get_table(
    table_code = "8888",
    territorial_level = "1",
    ibge_territorial_code = "all",
    variable = "12607",
    classifications = {"544": "129314"}, # Pega dados de produção física, industria geral (com ajuste sazonal)
    period = "all"
)
dados_brutos
# Out:
#                              NC                 NN  \
# 0    Nível Territorial (Código)  Nível Territorial
# 1                             1             Brasil
# 2                             1             Brasil
# 3                             1             Brasil
# 4                             1             Brasil
# ..                          ...                ...
# 264                           1             Brasil
# 265                           1             Brasil
# 266                           1             Brasil
# 267                           1             Brasil
# 268                           1             Brasil
#
#                              MC                 MN          V  \
# 0    Unidade de Medida (Código)  Unidade de Medida      Valor
# 1                            30      Número-índice   90.79220
# 2                            30      Número-índice   92.86861
# 3                            30      Número-índice   92.32088
# 4                            30      Número-índice   92.60123
# ..                          ...                ...        ...
# 264                          30      Número-índice  102.46812
# 265                          30      Número-índice  101.26158
# 266                          30      Número-índice  101.38224
# 267                          30      Número-índice  102.29717
# 268                          30      Número-índice  101.80709
#
#                  D1C     D1N           D2C             D2N                D3C  \
# 0    Brasil (Código)  Brasil  Mês (Código)             Mês  Variável (Código)
# 1                  1  Brasil        200201    janeiro 2002              12607
# 2                  1  Brasil        200202  fevereiro 2002              12607
# 3                  1  Brasil        200203      março 2002              12607
# 4                  1  Brasil        200204      abril 2002              12607
# ..               ...     ...           ...             ...                ...
# 264                1  Brasil        202312   dezembro 2023              12607
# 265                1  Brasil        202401    janeiro 2024              12607
# 266                1  Brasil        202402  fevereiro 2024              12607
# 267                1  Brasil        202403      março 2024              12607
# 268                1  Brasil        202404      abril 2024              12607
#
#                                                    D3N  \
# 0                                             Variável
# 1    PIMPF - Número-índice com ajuste sazonal (2022...
# 2    PIMPF - Número-índice com ajuste sazonal (2022...
# 3    PIMPF - Número-índice com ajuste sazonal (2022...
# 4    PIMPF - Número-índice com ajuste sazonal (2022...
# ..                                                 ...
# 264  PIMPF - Número-índice com ajuste sazonal (2022...
# 265  PIMPF - Número-índice com ajuste sazonal (2022...
# 266  PIMPF - Número-índice com ajuste sazonal (2022...
# 267  PIMPF - Número-índice com ajuste sazonal (2022...
# 268  PIMPF - Número-índice com ajuste sazonal (2022...
#
#                                                    D4C  \
# 0    Seções e atividades industriais (CNAE 2.0) (Có...
# 1                                               129314
# 2                                               129314
# 3                                               129314
# 4                                               129314
# ..                                                 ...
# 264                                             129314
# 265                                             129314
# 266                                             129314
# 267                                             129314
# 268                                             129314
#
#                                             D4N
# 0    Seções e atividades industriais (CNAE 2.0)
# 1                             1 Indústria geral
# 2                             1 Indústria geral
# 3                             1 Indústria geral
# 4                             1 Indústria geral
# ..                                          ...
# 264                           1 Indústria geral
# 265                           1 Indústria geral
# 266                           1 Indústria geral
# 267                           1 Indústria geral
# 268                           1 Indústria geral
#
# [269 rows x 13 columns]

# %%
# Tratamendo de dados
pim = (dados_brutos
    .rename(columns = dados_brutos.iloc[0])
    .drop(0)
    .rename(columns={"Mês (Código)":"Data"})
    .assign(
        Data = lambda x: pd.to_datetime(x.Data, format = "%Y%m"),
        Valor = lambda x: x.Valor.astype(float)
        )
)
pim = pim.pivot_table(columns="Variável", values="Valor", index="Data")
pim = pim.rename(columns={"PIMPF - Número-índice com ajuste sazonal (2022=100)":"PIM (Produção Física - Industria Geral) - SA"})
pim
# Out:
# Variável    PIM (Produção Física - Industria Geral) - SA
# Data
# 2002-01-01                                      90.79220
# 2002-02-01                                      92.86861
# 2002-03-01                                      92.32088
# 2002-04-01                                      92.60123
# 2002-05-01                                      92.49790
# ...                                                  ...
# 2023-12-01                                     102.46812
# 2024-01-01                                     101.26158
# 2024-02-01                                     101.38224
# 2024-03-01                                     102.29717
# 2024-04-01                                     101.80709
#
# [268 rows x 1 columns]

# %%
# Juntando tudo em um df só
atividade = pd.concat([pmc, pms, pim], axis=1).dropna()
atividade
# Out:
# Variável     PMC - SA   PMS - SA  PIM (Produção Física - Industria Geral) - SA
# Data
# 2011-01-01   91.46912   89.15232                                     119.99281
# 2011-02-01   93.31305   89.19171                                     121.31731
# 2011-03-01   93.90019   88.93554                                     121.97482
# 2011-04-01   93.83727   89.71568                                     118.70350
# 2011-05-01   94.98426   90.22346                                     122.38685
# ...               ...        ...                                           ...
# 2023-11-01  104.08078  102.69172                                     101.23978
# 2023-12-01  102.68449  103.22510                                     102.46812
# 2024-01-01  105.06961  103.70421                                     101.26158
# 2024-02-01  106.17007  102.77024                                     101.38224
# 2024-03-01  105.89179  103.18500                                     102.29717
#
# [159 rows x 3 columns]

# %% [markdown]
# # Gráfico

# %%
atividade.plot(subplots = True, layout = (3, 1), figsize = (15, 10), sharex=False)
# Out:
# array([[<Axes: xlabel='Data'>],
#        [<Axes: xlabel='Data'>],
#        [<Axes: xlabel='Data'>]], dtype=object)
